# %% [markdown]
# +----------------+
# |     Libro      |
# +----------------+
# | - id: int      |
# | - titulo: str  |
# | - isbn: str    |
# | - disponible: bool |
# +----------------+
# | + prestar()    |
# | + devolver()   |
# +----------------+
#         |
#         | pertenece a
#         v
# +----------------+
# |   Categoría    |
# +----------------+
# | - id: int      |
# | - nombre: str  |
# +----------------+
# | + agregarLibro()|
# +----------------+
#
# +----------------+
# |     Autor      |
# +----------------+
# | - id: int      |
# | - nombre: str  |
# | - nacionalidad: str |
# +----------------+
# | + escribirLibro()  |
# +----------------+
#         ^
#         | escribe
#         |
# +----------------+
# |     Libro      |
# +----------------+
#
# +----------------+
# |    Usuario     |
# +----------------+
# | - id: int      |
# | - nombre: str  |
# | - email: str   |
# +----------------+
# | + solicitarPrestamo() |
# | + devolverLibro()     |
# +----------------+
#         |
#         | hace
#         v
# +----------------+
# |   Prestamo     |
# +----------------+
# | - id: int      |
# | - fechaInicio: date |
# | - fechaFin: date    |
# | - devuelto: bool    |
# +----------------+
# | + registrarDevolucion() |
# +----------------+
